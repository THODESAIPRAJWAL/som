# %% [markdown]
# <a href="https://colab.research.google.com/github/THODESAIPRAJWAL/stockmarket-prediction/blob/main/NLPonstockmarket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install feedparser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting feedparser
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 3.9 MB/s eta 0:00:00
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6065 sha256=00ddc62b8f1ac08aa462051e89e39636eb431646dc5beda227b328bc9323d5b3
#   Stored in directory: /root/.cache/pip/wheels/65/7a/a7/78c287f64e401255dff4c13fdbc672fed5efbfd21c530114e1
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.10 sgmllib3k-1.0.0

# %%
# Import necessary libraries
import feedparser
import pandas as pd
import datetime

# Define the company you want to get news articles for
company = 'Tesla'

# Define the date range (last 30 days)
today = datetime.date.today()
last_month = today - datetime.timedelta(days=30)

# Create an empty list to store the articles
articles = []

# Loop through each day in the date range
current_day = last_month
while current_day <= today:
    # Format the date as a string
    date_string = current_day.strftime('%Y-%m-%d')

    # Get the news articles for the current day
    url = f'https://news.google.com/rss/search?q={company}%20after:{date_string}&hl=en-US&gl=US&ceid=US:en'
    news = feedparser.parse(url)

    # Add the articles to the list
    for article in news.entries:
        articles.append({
            'title': article.title,
            'description': article.summary,
            'link': article.link,
            'published': article.published
        })

    # Move on to the next day
    current_day += datetime.timedelta(days=1)

# Convert the list of articles to a Pandas DataFrame
df = pd.DataFrame(articles)

# Print the DataFrame
print(df.head())
# Out:
#                                                title  \
# 0  US House committee chair 'concerned' by Tesla ...
# 1  Tesla Cybertruck prototype spotted with new st...
# 2  Elon Musk Says Tesla Will Build Shanghai Batte...
# 3  Tesla is about to launch a big new software up...
# 4  2023.12 Official Tesla Release Notes - Softwar...
#
#                                          description  \
# 0  <a href="https://news.google.com/rss/articles/...
# 1  <a href="https://news.google.com/rss/articles/...
# 2  <ol><li><a href="https://news.google.com/rss/a...
# 3  <a href="https://news.google.com/rss/articles/...
# 4  <a href="https://news.google.com/rss/articles/...
#
#                                                 link  \
# 0  https://news.google.com/rss/articles/CBMieWh0d...
# 1  https://news.google.com/rss/articles/CBMiU2h0d...
# 2  https://news.google.com/rss/articles/CBMiWWh0d...
# 3  https://news.google.com/rss/articles/CBMiYWh0d...
# 4  https://news.google.com/rss/articles/CBMiS2h0d...
#
#                        published
# 0  Mon, 10 Apr 2023 22:48:00 GMT
# 1  Mon, 10 Apr 2023 23:46:00 GMT
# 2  Mon, 10 Apr 2023 01:02:40 GMT
# 3  Mon, 10 Apr 2023 15:05:00 GMT
# 4  Mon, 10 Apr 2023 12:16:48 GMT

# %%
df
# Out:
#                                                   title  \
# 0     US House committee chair 'concerned' by Tesla ...
# 1     Tesla Cybertruck prototype spotted with new st...
# 2     Elon Musk Says Tesla Will Build Shanghai Batte...
# 3     Tesla is about to launch a big new software up...
# 4     2023.12 Official Tesla Release Notes - Softwar...
# ...                                                 ...
# 3149  EXCLUSIVE: Top 10 Most Searched Tickers On Ben...
# 3150  Warren Buffett-backed BYD announces new shock ...
# 3151  Now That Elon Musk Is Labeling NPR And The BBC...
# 3152  NHTSA investigates Tesla that failed to stop f...
# 3153  Thinking about trading options or stock in Mic...
#
#                                             description  \
# 0     <a href="https://news.google.com/rss/articles/...
# 1     <a href="https://news.google.com/rss/articles/...
# 2     <ol><li><a href="https://news.google.com/rss/a...
# 3     <a href="https://news.google.com/rss/articles/...
# 4     <a href="https://news.google.com/rss/articles/...
# ...                                                 ...
# 3149  <a href="https://news.google.com/rss/articles/...
# 3150  <a href="https://news.google.com/rss/articles/...
# 3151  <a href="https://news.google.com/rss/articles/...
# 3152  <a href="https://news.google.com/rss/articles/...
# 3153  <a href="https://news.google.com/rss/articles/...
#
#                                                    link  \
# 0     https://news.google.com/rss/articles/CBMieWh0d...
# 1     https://news.google.com/rss/articles/CBMiU2h0d...
# 2     https://news.google.com/rss/articles/CBMiWWh0d...
# 3     https://news.google.com/rss/articles/CBMiYWh0d...
# 4     https://news.google.com/rss/articles/CBMiS2h0d...
# ...                                                 ...
# 3149  https://news.google.com/rss/articles/CBMijwFod...
# 3150  https://news.google.com/rss/articles/CBMiSmh0d...
# 3151  https://news.google.com/rss/articles/CBMinQFod...
# 3152  https://news.google.com/rss/articles/CBMieGh0d...
# 3153  https://news.google.com/rss/articles/CBMimQFod...
#
#                           published
# 0     Mon, 10 Apr 2023 22:48:00 GMT
# 1     Mon, 10 Apr 2023 23:46:00 GMT
# 2     Mon, 10 Apr 2023 01:02:40 GMT
# 3     Mon, 10 Apr 2023 15:05:00 GMT
# 4     Mon, 10 Apr 2023 12:16:48 GMT
# ...                             ...
# 3149  Mon, 10 Apr 2023 19:02:47 GMT
# 3150  Mon, 10 Apr 2023 17:20:05 GMT
# 3151  Mon, 10 Apr 2023 19:09:00 GMT
# 3152  Mon, 10 Apr 2023 18:42:29 GMT
# 3153  Mon, 10 Apr 2023 13:31:00 GMT
#
# [3154 rows x 4 columns]

# %%
# Install the GoogleNews library
# !pip install GoogleNews

# Import necessary libraries
from GoogleNews import GoogleNews
import pandas as pd
import datetime

# Set up the Google News API
googlenews = GoogleNews()

# Define the company you want to get news articles for
company = 'Tesla'

# Define the date range (last 30 days)
today = datetime.date.today()
last_month = today - datetime.timedelta(days=30)

# Create an empty list to store the articles
articles = []

# Loop through each day in the date range
current_day = last_month
while current_day <= today:
    # Format the date as a string
    date_string = current_day.strftime('%m/%d/%Y')

    # Define the API parameters
    query = company
    period = 'd30'
    custom_query = f'{query} after:{date_string} before:{today.strftime("%m/%d/%Y")}'
    googlenews.clear()
    googlenews.search(custom_query)
    googlenews.get_page(1)

    # Send the API request
    response = googlenews.result()

    # Add the articles to the list
    for article in response:
        articles.append({
            'title': article['title'],
            'description': article['desc'],
            'link': article['link'],
            'published': article['date']
        })

    # Move on to the next day
    current_day += datetime.timedelta(days=1)

# Convert the list of articles to a Pandas DataFrame
df = pd.DataFrame(articles)

# Print the DataFrame
print(df.head())
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting GoogleNews
#   Downloading GoogleNews-1.6.7-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from GoogleNews) (4.11.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from GoogleNews) (2.8.2)
# Collecting dateparser
#   Downloading dateparser-1.1.8-py2.py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.8/293.8 kB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->GoogleNews) (2.4)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.9/dist-packages (from dateparser->GoogleNews) (2022.10.31)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.9/dist-packages (from dateparser->GoogleNews) (4.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.9/dist-packages (from dateparser->GoogleNews) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil->GoogleNews) (1.16.0)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.9/dist-packages (from tzlocal->dateparser->GoogleNews) (0.1.0.post0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.9/dist-packages (from pytz-deprecation-shim->tzlocal->dateparser->GoogleNews) (2023.3)
# Installing collected packages: dateparser, GoogleNews
# Successfully installed GoogleNews-1.6.7 dateparser-1.1.8
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
#                                                title  \
# 0  Dividend Calendar as of Apr 8th | Dividends Today
# 1  Dividend Calendar as of Apr 8th | Dividends Today
# 2  Dividend Calendar as of Apr 8th | Dividends Today
# 3  Dividend Calendar as of Apr 8th | Dividends Today
# 4  Dividend Calendar as of Apr 8th | Dividends Today
#
#                                          description  \
# 0  The table below is a list view calendar of sto...
# 1  The table below is a list view calendar of sto...
# 2  The table below is a list view calendar of sto...
# 3  The table below is a list view calendar of sto...
# 4  The table below is a list view calendar of sto...
#
#                                            link     published
# 0  https://www.benzinga.com/calendars/dividends  Apr 19, 2021
# 1  https://www.benzinga.com/calendars/dividends  Apr 19, 2021
# 2  https://www.benzinga.com/calendars/dividends  Apr 19, 2021
# 3  https://www.benzinga.com/calendars/dividends  Apr 19, 2021
# 4  https://www.benzinga.com/calendars/dividends  Apr 19, 2021

# %%
df
# Out:
#                                                 title  \
# 0   Dividend Calendar as of Apr 8th | Dividends Today
# 1   Dividend Calendar as of Apr 8th | Dividends Today
# 2   Dividend Calendar as of Apr 8th | Dividends Today
# 3   Dividend Calendar as of Apr 8th | Dividends Today
# 4   Dividend Calendar as of Apr 8th | Dividends Today
# ..                                                ...
# 73  Check Out Full List Of Forbes’ 25 World Billio...
# 74  AGM - Distance Voting Ballot - Annual General ...
# 75  EGM - Distance Voting Ballot - Extraordinary G...
# 76  Ford Stock Down Four Percent During Week Of Fe...
# 77  Dividend Calendar as of Apr 8th | Dividends Today
#
#                                           description  \
# 0   The table below is a list view calendar of sto...
# 1   The table below is a list view calendar of sto...
# 2   The table below is a list view calendar of sto...
# 3   The table below is a list view calendar of sto...
# 4   The table below is a list view calendar of sto...
# ..                                                ...
# 73  Forbes in its 2023 list of 25 richest people i...
# 74  IRB - BRASIL RESSEGUROS S.A. to be held on 04/...
# 75  IRB - BRASIL RESSEGUROS S.A. to be held on 04/...
# 76  Ford stock dipped by four percent or $0.50 per...
# 77  The table below is a list view calendar of sto...
#
#                                                  link     published
# 0        https://www.benzinga.com/calendars/dividends  Apr 19, 2021
# 1        https://www.benzinga.com/calendars/dividends  Apr 19, 2021
# 2        https://www.benzinga.com/calendars/dividends  Apr 19, 2021
# 3        https://www.benzinga.com/calendars/dividends  Apr 19, 2021
# 4        https://www.benzinga.com/calendars/dividends  Apr 19, 2021
# ..                                                ...           ...
# 73  https://www.gistmania.com/talk/topic,558984.0....    4 days ago
# 74  https://www.marketscreener.com/quote/stock/IRB...   1 month ago
# 75  https://www.marketscreener.com/quote/stock/IRB...   1 month ago
# 76  https://fordauthority.com/2023/02/ford-stock-v...  Feb 11, 2023
# 77       https://www.benzinga.com/calendars/dividends  Apr 19, 2021
#
# [78 rows x 4 columns]

# %%
import requests
import pandas as pd

url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&limit=200&apikey=M3313X5M5V6BJGMO'
r = requests.get(url)
data = r.json()

# Normalize the JSON data into a pandas dataframe
df = pd.json_normalize(data['feed'])

# Print the dataframe
print(df)
# Out:
#                                                  title  \
# 0    Apple Digital Services Hit By Massive Outage -...
# 1    Amid big drop in sales, PC makers may soon be ...
# 2    TSLA, AAPL, RIOT, AMC, EBS: Top Trending Stock...
# 3    Smart Speaker Market size to grow by USD 16,65...
# 4    Tablet Application Processor Market size to gr...
# ..                                                 ...
# 195  Prediction: These 7 Stocks Will Be Worth Over ...
# 196  Apple Stock Is Nearing Its Previous Peak. iPho...
# 197  How does Apple's Pay Later work, and should yo...
# 198  Big Apple Watch OS Interface Overhaul Coming U...
# 199  Musk's Twitter antics keep some advertisers aw...
#
#                                                    url   time_published  \
# 0    https://www.benzinga.com/news/23/04/31736994/a...  20230411T035545
# 1    https://www.marketwatch.com/story/amid-big-dro...  20230411T014300
# 2    https://www.benzinga.com/economics/macro-econo...  20230411T012030
# 3    https://www.prnewswire.com/news-releases/smart...  20230411T000000
# 4    https://www.prnewswire.com/news-releases/table...  20230410T223000
# ..                                                 ...              ...
# 195  https://www.fool.com/investing/2023/04/03/pred...  20230403T095500
# 196  https://www.barrons.com/articles/apple-stock-i...  20230403T092200
# 197  https://www.marketwatch.com/story/how-does-app...  20230403T090100
# 198  https://www.benzinga.com/news/23/04/31625762/a...  20230403T060127
# 199  https://www.financialexpress.com/industry/elon...  20230403T052626
#
#                authors                                            summary  \
# 0     [Ananya Gairola]  Some Apple Inc. AAPL users were left baffled a...
# 1    [Therese Poletti]  While the big drop in Apple Inc.'s Mac sales g...
# 2        [Bhavik Nair]  U.S. markets closed mixed on Monday as investo...
# 3          [Technavio]  Smart Speaker Market size to grow by USD 16,65...
# 4          [Technavio]  Tablet Application Processor Market size to gr...
# ..                 ...                                                ...
# 195   [Keith Speights]  Looking for the biggest giants of the future? ...
# 196       [Adam Clark]  Apple Stock Nears Previous Peak. iPhone Demand...
# 197    [Jackie Veling]  Although it is zero interest and no fees, fina...
# 198   [Ananya Gairola]  Apple Inc. AAPL Watch users can look forward t...
# 199                 []  Musk's Twitter antics keep some advertisers aw...
#
#                                           banner_image                 source  \
# 0    https://cdn.benzinga.com/files/images/story/20...               Benzinga
# 1             https://images.mktw.net/im-761192/social            MarketWatch
# 2    https://cdn.benzinga.com/files/images/story/20...               Benzinga
# 3    https://mma.prnewswire.com/media/2049353/Techn...            PR Newswire
# 4    https://mma.prnewswire.com/media/2049349/Techn...            PR Newswire
# ..                                                 ...                    ...
# 195  https://g.foolcdn.com/image/?url=https%3A%2F%2...            Motley Fool
# 196        https://images.barrons.com/im-650616/social                Barrons
# 197           https://images.mktw.net/im-755423/social            MarketWatch
# 198  https://cdn.benzinga.com/files/images/story/20...               Benzinga
# 199  https://www.financialexpress.com/wp-content/up...  The Financial Express
#
#     category_within_source             source_domain  \
# 0                     News          www.benzinga.com
# 1              Top Stories       www.marketwatch.com
# 2                  Markets          www.benzinga.com
# 3                      n/a        www.prnewswire.com
# 4                      n/a        www.prnewswire.com
# ..                     ...                       ...
# 195                    n/a              www.fool.com
# 196                    n/a           www.barrons.com
# 197            Top Stories       www.marketwatch.com
# 198                   News          www.benzinga.com
# 199                    n/a  www.financialexpress.com
#
#                                                 topics  \
# 0    [{'topic': 'Technology', 'relevance_score': '1...
# 1    [{'topic': 'Technology', 'relevance_score': '1...
# 2    [{'topic': 'Economy - Monetary', 'relevance_sc...
# 3    [{'topic': 'Economy - Monetary', 'relevance_sc...
# 4    [{'topic': 'Economy - Monetary', 'relevance_sc...
# ..                                                 ...
# 195  [{'topic': 'Retail & Wholesale', 'relevance_sc...
# 196  [{'topic': 'Technology', 'relevance_score': '1...
# 197  [{'topic': 'Technology', 'relevance_score': '1...
# 198  [{'topic': 'Technology', 'relevance_score': '1...
# 199  [{'topic': 'Technology', 'relevance_score': '0...
#
#      overall_sentiment_score overall_sentiment_label  \
# 0                  -0.132056                 Neutral
# 1                  -0.059768                 Neutral
# 2                   0.064371                 Neutral
# 3                   0.281867        Somewhat-Bullish
# 4                   0.151807        Somewhat-Bullish
# ..                       ...                     ...
# 195                 0.190874        Somewhat-Bullish
# 196                 0.092187                 Neutral
# 197                 0.070234                 Neutral
# 198                 0.027978                 Neutral
# 199                 0.014405                 Neutral
#
#                                       ticker_sentiment
# 0    [{'ticker': 'AAPL', 'relevance_score': '0.9428...
# 1    [{'ticker': 'HPQ', 'relevance_score': '0.14646...
# 2    [{'ticker': 'AAPL', 'relevance_score': '0.2503...
# 3    [{'ticker': 'LNVGF', 'relevance_score': '0.034...
# 4    [{'ticker': 'MXL', 'relevance_score': '0.01197...
# ..                                                 ...
# 195  [{'ticker': 'MSFT', 'relevance_score': '0.2842...
# 196  [{'ticker': 'AAPL', 'relevance_score': '0.9444...
# 197  [{'ticker': 'AAPL', 'relevance_score': '0.7901...
# 198  [{'ticker': 'AAPL', 'relevance_score': '0.8338...
# 199  [{'ticker': 'HLT', 'relevance_score': '0.02671...
#
# [200 rows x 13 columns]

# %%
df
# Out:
#                                                  title  \
# 0    Apple Digital Services Hit By Massive Outage -...
# 1    Amid big drop in sales, PC makers may soon be ...
# 2    TSLA, AAPL, RIOT, AMC, EBS: Top Trending Stock...
# 3    Smart Speaker Market size to grow by USD 16,65...
# 4    Tablet Application Processor Market size to gr...
# ..                                                 ...
# 195  Prediction: These 7 Stocks Will Be Worth Over ...
# 196  Apple Stock Is Nearing Its Previous Peak. iPho...
# 197  How does Apple's Pay Later work, and should yo...
# 198  Big Apple Watch OS Interface Overhaul Coming U...
# 199  Musk's Twitter antics keep some advertisers aw...
#
#                                                    url   time_published  \
# 0    https://www.benzinga.com/news/23/04/31736994/a...  20230411T035545
# 1    https://www.marketwatch.com/story/amid-big-dro...  20230411T014300
# 2    https://www.benzinga.com/economics/macro-econo...  20230411T012030
# 3    https://www.prnewswire.com/news-releases/smart...  20230411T000000
# 4    https://www.prnewswire.com/news-releases/table...  20230410T223000
# ..                                                 ...              ...
# 195  https://www.fool.com/investing/2023/04/03/pred...  20230403T095500
# 196  https://www.barrons.com/articles/apple-stock-i...  20230403T092200
# 197  https://www.marketwatch.com/story/how-does-app...  20230403T090100
# 198  https://www.benzinga.com/news/23/04/31625762/a...  20230403T060127
# 199  https://www.financialexpress.com/industry/elon...  20230403T052626
#
#                authors                                            summary  \
# 0     [Ananya Gairola]  Some Apple Inc. AAPL users were left baffled a...
# 1    [Therese Poletti]  While the big drop in Apple Inc.'s Mac sales g...
# 2        [Bhavik Nair]  U.S. markets closed mixed on Monday as investo...
# 3          [Technavio]  Smart Speaker Market size to grow by USD 16,65...
# 4          [Technavio]  Tablet Application Processor Market size to gr...
# ..                 ...                                                ...
# 195   [Keith Speights]  Looking for the biggest giants of the future? ...
# 196       [Adam Clark]  Apple Stock Nears Previous Peak. iPhone Demand...
# 197    [Jackie Veling]  Although it is zero interest and no fees, fina...
# 198   [Ananya Gairola]  Apple Inc. AAPL Watch users can look forward t...
# 199                 []  Musk's Twitter antics keep some advertisers aw...
#
#                                           banner_image                 source  \
# 0    https://cdn.benzinga.com/files/images/story/20...               Benzinga
# 1             https://images.mktw.net/im-761192/social            MarketWatch
# 2    https://cdn.benzinga.com/files/images/story/20...               Benzinga
# 3    https://mma.prnewswire.com/media/2049353/Techn...            PR Newswire
# 4    https://mma.prnewswire.com/media/2049349/Techn...            PR Newswire
# ..                                                 ...                    ...
# 195  https://g.foolcdn.com/image/?url=https%3A%2F%2...            Motley Fool
# 196        https://images.barrons.com/im-650616/social                Barrons
# 197           https://images.mktw.net/im-755423/social            MarketWatch
# 198  https://cdn.benzinga.com/files/images/story/20...               Benzinga
# 199  https://www.financialexpress.com/wp-content/up...  The Financial Express
#
#     category_within_source             source_domain  \
# 0                     News          www.benzinga.com
# 1              Top Stories       www.marketwatch.com
# 2                  Markets          www.benzinga.com
# 3                      n/a        www.prnewswire.com
# 4                      n/a        www.prnewswire.com
# ..                     ...                       ...
# 195                    n/a              www.fool.com
# 196                    n/a           www.barrons.com
# 197            Top Stories       www.marketwatch.com
# 198                   News          www.benzinga.com
# 199                    n/a  www.financialexpress.com
#
#                                                 topics  \
# 0    [{'topic': 'Technology', 'relevance_score': '1...
# 1    [{'topic': 'Technology', 'relevance_score': '1...
# 2    [{'topic': 'Economy - Monetary', 'relevance_sc...
# 3    [{'topic': 'Economy - Monetary', 'relevance_sc...
# 4    [{'topic': 'Economy - Monetary', 'relevance_sc...
# ..                                                 ...
# 195  [{'topic': 'Retail & Wholesale', 'relevance_sc...
# 196  [{'topic': 'Technology', 'relevance_score': '1...
# 197  [{'topic': 'Technology', 'relevance_score': '1...
# 198  [{'topic': 'Technology', 'relevance_score': '1...
# 199  [{'topic': 'Technology', 'relevance_score': '0...
#
#      overall_sentiment_score overall_sentiment_label  \
# 0                  -0.132056                 Neutral
# 1                  -0.059768                 Neutral
# 2                   0.064371                 Neutral
# 3                   0.281867        Somewhat-Bullish
# 4                   0.151807        Somewhat-Bullish
# ..                       ...                     ...
# 195                 0.190874        Somewhat-Bullish
# 196                 0.092187                 Neutral
# 197                 0.070234                 Neutral
# 198                 0.027978                 Neutral
# 199                 0.014405                 Neutral
#
#                                       ticker_sentiment
# 0    [{'ticker': 'AAPL', 'relevance_score': '0.9428...
# 1    [{'ticker': 'HPQ', 'relevance_score': '0.14646...
# 2    [{'ticker': 'AAPL', 'relevance_score': '0.2503...
# 3    [{'ticker': 'LNVGF', 'relevance_score': '0.034...
# 4    [{'ticker': 'MXL', 'relevance_score': '0.01197...
# ..                                                 ...
# 195  [{'ticker': 'MSFT', 'relevance_score': '0.2842...
# 196  [{'ticker': 'AAPL', 'relevance_score': '0.9444...
# 197  [{'ticker': 'AAPL', 'relevance_score': '0.7901...
# 198  [{'ticker': 'AAPL', 'relevance_score': '0.8338...
# 199  [{'ticker': 'HLT', 'relevance_score': '0.02671...
#
# [200 rows x 13 columns]

# %%
import pandas as pd
import datetime

# Get today's date as a string
today_str = datetime.date.today().strftime('%Y-%m-%d')

# Filter the DataFrame to include only rows where time_published is today
today_df = df[df['time_published'] == today_str]

# Get the columns you're interested in
cols_of_interest = ['title', 'overall_sentiment_score', 'overall_sentiment_label','ticker_sentiment']
result_df = today_df[cols_of_interest]

# Show the resulting DataFrame
print(result_df)
# Out:
# Empty DataFrame
# Columns: [title, overall_sentiment_score, overall_sentiment_label, ticker_sentiment]
# Index: []

# %%
import pandas as pd
import datetime


# Convert the time_published column to a datetime object
df['time_published'] = pd.to_datetime(df['time_published'], format='%Y-%m-%d')

# Sort the DataFrame by the time_published column
df = df.sort_values('time_published')

# Get today's date as a datetime object
today = datetime.date.today()

# Get the columns you're interested in
cols_of_interest = ['title','time_published','overall_sentiment_score', 'overall_sentiment_label', 'ticker_sentiment']
result_df = df[cols_of_interest]

# Show the resulting DataFrame
result_df
# Out:
#                                                  title      time_published  \
# 199  Musk's Twitter antics keep some advertisers aw... 2023-04-03 05:26:26
# 198  Big Apple Watch OS Interface Overhaul Coming U... 2023-04-03 06:01:27
# 197  How does Apple's Pay Later work, and should yo... 2023-04-03 09:01:00
# 196  Apple Stock Is Nearing Its Previous Peak. iPho... 2023-04-03 09:22:00
# 195  Prediction: These 7 Stocks Will Be Worth Over ... 2023-04-03 09:55:00
# ..                                                 ...                 ...
# 4    Tablet Application Processor Market size to gr... 2023-04-10 22:30:00
# 3    Smart Speaker Market size to grow by USD 16,65... 2023-04-11 00:00:00
# 2    TSLA, AAPL, RIOT, AMC, EBS: Top Trending Stock... 2023-04-11 01:20:30
# 1    Amid big drop in sales, PC makers may soon be ... 2023-04-11 01:43:00
# 0    Apple Digital Services Hit By Massive Outage -... 2023-04-11 03:55:45
#
#      overall_sentiment_score overall_sentiment_label  \
# 199                 0.014405                 Neutral
# 198                 0.027978                 Neutral
# 197                 0.070234                 Neutral
# 196                 0.092187                 Neutral
# 195                 0.190874        Somewhat-Bullish
# ..                       ...                     ...
# 4                   0.151807        Somewhat-Bullish
# 3                   0.281867        Somewhat-Bullish
# 2                   0.064371                 Neutral
# 1                  -0.059768                 Neutral
# 0                  -0.132056                 Neutral
#
#                                       ticker_sentiment
# 199  [{'ticker': 'HLT', 'relevance_score': '0.02671...
# 198  [{'ticker': 'AAPL', 'relevance_score': '0.8338...
# 197  [{'ticker': 'AAPL', 'relevance_score': '0.7901...
# 196  [{'ticker': 'AAPL', 'relevance_score': '0.9444...
# 195  [{'ticker': 'MSFT', 'relevance_score': '0.2842...
# ..                                                 ...
# 4    [{'ticker': 'MXL', 'relevance_score': '0.01197...
# 3    [{'ticker': 'LNVGF', 'relevance_score': '0.034...
# 2    [{'ticker': 'AAPL', 'relevance_score': '0.2503...
# 1    [{'ticker': 'HPQ', 'relevance_score': '0.14646...
# 0    [{'ticker': 'AAPL', 'relevance_score': '0.9428...
#
# [200 rows x 5 columns]

# %%
df = pd.json_normalize(result_df['ticker_sentiment'][0])
df['title'] = result_df['title'][0]
df['time_published'] = result_df['time_published'][0]
df['overall_sentiment_score'] = result_df['overall_sentiment_score'][0]
df['overall_sentiment_label'] = result_df['overall_sentiment_label'][0]

for i in range(len(result_df)):
    df1 = pd.json_normalize(result_df['ticker_sentiment'][i])
    df1['title'] = result_df['title'][i]
    df1['time_published'] = result_df['time_published'][i]
    df1['overall_sentiment_score'] = result_df['overall_sentiment_score'][i]
    df1['overall_sentiment_label'] = result_df['overall_sentiment_label'][i]
    df = pd.concat([df, df1], ignore_index=True)
    # do something with the resulting dataframe 'df'
    # for example, you can concatenate it to a bigger dataframe

result_df = df

# %%
result_df
# Out:
#      ticker relevance_score ticker_sentiment_score ticker_sentiment_label  \
# 0      AAPL        0.942886              -0.318243       Somewhat-Bearish
# 1      AAPL        0.942886              -0.318243       Somewhat-Bearish
# 2       HPQ        0.146469               0.171033       Somewhat-Bullish
# 3     LNVGF        0.073546                0.13385                Neutral
# 4      MSFT        0.146469              -0.199398       Somewhat-Bearish
# ...     ...             ...                    ...                    ...
# 1009     KO         0.05339              -0.025986                Neutral
# 1010      T         0.02671              -0.080406                Neutral
# 1011     MS         0.05339               0.007003                Neutral
# 1012    WBD         0.02671               0.034446                Neutral
# 1013    IAS         0.02671              -0.066694                Neutral
#
#                                                   title      time_published  \
# 0     Apple Digital Services Hit By Massive Outage -... 2023-04-11 03:55:45
# 1     Apple Digital Services Hit By Massive Outage -... 2023-04-11 03:55:45
# 2     Amid big drop in sales, PC makers may soon be ... 2023-04-11 01:43:00
# 3     Amid big drop in sales, PC makers may soon be ... 2023-04-11 01:43:00
# 4     Amid big drop in sales, PC makers may soon be ... 2023-04-11 01:43:00
# ...                                                 ...                 ...
# 1009  Musk's Twitter antics keep some advertisers aw... 2023-04-03 05:26:26
# 1010  Musk's Twitter antics keep some advertisers aw... 2023-04-03 05:26:26
# 1011  Musk's Twitter antics keep some advertisers aw... 2023-04-03 05:26:26
# 1012  Musk's Twitter antics keep some advertisers aw... 2023-04-03 05:26:26
# 1013  Musk's Twitter antics keep some advertisers aw... 2023-04-03 05:26:26
#
#       overall_sentiment_score overall_sentiment_label
# 0                   -0.132056                 Neutral
# 1                   -0.132056                 Neutral
# 2                   -0.059768                 Neutral
# 3                   -0.059768                 Neutral
# 4                   -0.059768                 Neutral
# ...                       ...                     ...
# 1009                 0.014405                 Neutral
# 1010                 0.014405                 Neutral
# 1011                 0.014405                 Neutral
# 1012                 0.014405                 Neutral
# 1013                 0.014405                 Neutral
#
# [1014 rows x 8 columns]

# %%
result_df['ticker'].unique()
# Out:
# array(['AAPL', 'HPQ', 'LNVGF', 'MSFT', 'GOOG', 'DELL', 'RIOT', 'TSLA',
#        'APE', 'EBS', 'CRYPTO:BTC', 'NFLX', 'SNEJF', 'SSNLF', 'QCOM',
#        'BIDU', 'NXPI', 'BGOUF', 'SONO', 'MXL', 'NVDA', 'AVGO', 'RNECF',
#        'TXN', 'INTC', 'AMD', 'TOSBF', 'MCHP', 'PYPL', 'DG', 'BAC', 'DLTR',
#        'BRK-A', 'UA', 'OXY', 'COST', 'FIVE', 'MA', 'V', 'CDNS', 'Z', 'SQ',
#        'OLLI', 'C', 'CSCO', 'JPM', 'VRTX', 'DAL', 'UNH', 'WFC', 'CAT',
#        'NOW', 'XOM', 'PXD', 'BA', 'ADBE', 'ORCL', 'GDVM', 'GBIO', 'META',
#        'IMPP', 'BBBY', 'CVNA', 'IVZ', 'MRNA', 'AMZN', 'MULN', 'DBX',
#        'PCAR', 'CVX', 'FANG', 'LRCX', 'VORB', 'HNHPF', 'GM', 'RYLPF',
#        'ESALF', 'FOX', 'FRC', 'HCTI', 'QBTS', 'COCP', 'GME', 'MU', 'WDC',
#        'CIEN', 'CCZ', 'LITE', 'MRVL', 'AXON', 'NKE', 'AXP', 'PACW', 'WAL',
#        'CMA', 'SCHW', 'KO', 'EADSF', 'BYDDF', 'SBUX', 'ATVI', 'GILD',
#        'ABNB', 'BFLY', 'CRYPTO:DOGE', 'RIVN', 'ZLNDY', 'XMTR', 'CRWD',
#        'PLUG', 'T', 'RS', 'UNM', 'LECO', 'HD', 'BABA', 'ISRG', 'SHOP',
#        'CURN', 'SBNY', 'LMT', 'ORLY', 'MANH', 'UAL', 'PAYX', 'WBA',
#        'CHKIF', 'JPNRF', 'CEAYY', 'HOOD', 'STZ', 'SCCO', 'WT', 'FDX',
#        'GS', 'RBLX', 'SPOT', 'WMT', 'MDNDF', 'MCD', 'SCLX', 'MS', 'SKY',
#        'MKTX', 'HSY', 'PD', 'FOREX:USD', 'DSSMY', 'PLTR', 'NYT', 'VZIO',
#        'LPL', 'OLED', 'SPGI', 'PDD', 'CGCO', 'AZN', 'JNJ', 'RGLD', 'AEP',
#        'XEL', 'PATH', 'NTDOF', 'UBS', 'CS', 'EXEL', 'SMPL', 'APO', 'SYF',
#        'ANET', 'KRUS', 'DEI', 'FTNT', 'PCRFF', 'F', 'PG', 'LLY', 'WBD',
#        'FOREX:GBP', 'MORN', 'BFC', 'MTD', 'AZO', 'ATKR', 'RIO', 'NUE',
#        'LSI', 'WWE', 'LW', 'SIRI', 'URI', 'NEM', 'CHTR', 'CMG', 'HUBS',
#        'EXR', 'STLD', 'CRYPTO:NEM', 'DVN', 'KMX', 'EBAY', 'BLK', 'TRMNF',
#        'UPS', 'BBY', 'ACB', 'BIO', 'NVS', 'PFE', 'PHG', 'TRIB', 'ABT',
#        'MJNA', 'IBM', 'MDT', 'GE', 'FOREX:UZS', 'AYI', 'SGH', 'MSM',
#        'HHUSF', 'TSM', 'NIO', 'PANW', 'SNAP', 'LYV', 'BOOT', 'EDR', 'HAL',
#        'LVS', 'WYNN', 'TRI', 'RNSDF', 'MPC', 'SLB', 'RMBS', 'MRO', 'DIS',
#        'BB', 'BRZE', 'LAC', 'MCQEF', 'CRYPTO:SHIB', 'WDAY', 'ACN',
#        'CRYPTO:XCP', 'PRFUF', 'ROKU', 'STT', 'NRDS', 'HLT', 'MDLZ', 'DV',
#        'IAS'], dtype=object)

# %%
news = result_df.loc[result_df['ticker'] == 'MSFT']

# %%
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76 entries, 4 to 994
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ticker                   76 non-null     object
#  1   relevance_score          76 non-null     object
#  2   ticker_sentiment_score   76 non-null     object
#  3   ticker_sentiment_label   76 non-null     object
#  4   title                    76 non-null     object
#  5   time_published           76 non-null     datetime64[ns]
#  6   overall_sentiment_score  76 non-null     float64
#  7   overall_sentiment_label  76 non-null     object
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 5.3+ KB

# %%
news['time_published'] = pd.to_datetime(news['time_published'])
news['date'] = news['time_published'].dt.date
news.drop('time_published', axis=1, inplace=True)
news
# Out:
# <ipython-input-15-f10046ef671c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news['time_published'] = pd.to_datetime(news['time_published'])
# <ipython-input-15-f10046ef671c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news['date'] = news['time_published'].dt.date
# <ipython-input-15-f10046ef671c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news.drop('time_published', axis=1, inplace=True)
#     ticker relevance_score ticker_sentiment_score ticker_sentiment_label  \
# 4     MSFT        0.146469              -0.199398       Somewhat-Bearish
# 63    MSFT        0.119088               0.132503                Neutral
# 74    MSFT        0.102013               0.115492                Neutral
# 91    MSFT        0.065061               0.022336                Neutral
# 93    MSFT        0.240965               0.082144                Neutral
# ..     ...             ...                    ...                    ...
# 967   MSFT        0.040691                    0.0                Neutral
# 981   MSFT        0.114956               0.056579                Neutral
# 984   MSFT         0.13459                0.06791                Neutral
# 987   MSFT        0.096283                0.22101       Somewhat-Bullish
# 994   MSFT          0.2842               0.240974       Somewhat-Bullish
#
#                                                  title  \
# 4    Amid big drop in sales, PC makers may soon be ...
# 63   Futures: Big Bank Earnings, Key Inflation Data...
# 74   Stock Market Today: Stocks Close Mixed on Rate...
# 91   12 charts show a global recession has already ...
# 93   Why Apple, Amazon, Alphabet, and Microsoft All...
# ..                                                 ...
# 967     Zacks Industry Outlook Highlights Apple and HP
# 981  Is iShares ESG Aware MSCI USA ETF  ( ESGU )  a...
# 984  Should SPDR Portfolio S&P 500 ETF  ( SPLG )  B...
# 987  S&P, Nasdaq futures fall on inflation worries ...
# 994  Prediction: These 7 Stocks Will Be Worth Over ...
#
#      overall_sentiment_score overall_sentiment_label        date
# 4                  -0.059768                 Neutral  2023-04-11
# 63                  0.092350                 Neutral  2023-04-10
# 74                  0.141363                 Neutral  2023-04-10
# 91                 -0.148991                 Neutral  2023-04-10
# 93                  0.053586                 Neutral  2023-04-10
# ..                       ...                     ...         ...
# 967                 0.257118        Somewhat-Bullish  2023-04-03
# 981                 0.248949        Somewhat-Bullish  2023-04-03
# 984                 0.175513        Somewhat-Bullish  2023-04-03
# 987                -0.026354                 Neutral  2023-04-03
# 994                 0.190874        Somewhat-Bullish  2023-04-03
#
# [76 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create a scatter plot with the index of the DataFrame as x and the Overall_sentiment_score column as y
fig, ax = plt.subplots(figsize=(8, 6))
ax.scatter(news.index, news['overall_sentiment_score'], color='#0077be', alpha=0.5)

# Add labels and title
ax.set_xlabel('Index', fontsize=12)
ax.set_ylabel('Overall Sentiment Score', fontsize=12)
ax.set_title('Overall Sentiment Scores by Index', fontsize=14)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sort the data by time_published column
news = news.sort_values('date')

# Create a line plot with the time_published column as x and the Overall_sentiment_score column as y
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(news['date'], news['overall_sentiment_score'], color='#0077be', alpha=0.8)

# Add labels and title
ax.set_xlabel('Date Published', fontsize=12)
ax.set_ylabel('Overall Sentiment Score', fontsize=12)
ax.set_title('Overall Sentiment Scores Over Time', fontsize=14)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import dates as mpl_dates
#from mpldatacursor import datacursor


# Sort the data by time_published column
news = news.sort_values('date')

# Create a line plot with the time_published column as x and the Overall_sentiment_score column as y
fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(news['date'], news['overall_sentiment_score'], color='#0077be', alpha=0.8)

# Add labels and title
ax.set_xlabel('Date Published', fontsize=12)
ax.set_ylabel('Overall Sentiment Score', fontsize=12)
ax.set_title('Overall Sentiment Scores Over Time', fontsize=14)

# Format the x-axis as dates
date_fmt = mpl_dates.DateFormatter('%b %d, %Y')
ax.xaxis.set_major_formatter(date_fmt)
plt.xticks(rotation=45, ha='right')


# Show the plot
plt.show()

# %%
# set the figure size and create subplots
fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(12,8))
fig.subplots_adjust(hspace=0.4)

# plot the line graph
pivot_table = news.pivot_table(index='date', values='overall_sentiment_score')
pivot_table.plot(kind='line', ax=ax1)
ax1.set_title("Overall Sentiment Score over Time", )

# plot the bar graph
news_bar = news.groupby(['date', 'overall_sentiment_label'])['overall_sentiment_score'].sum().unstack()
news_bar.plot(kind='bar', stacked=True, ax=ax2)
ax2.set_xlabel('Date')
ax2.set_ylabel('Overall Sentiment Score')
ax2.legend(title='Sentiment Label', loc='upper left')
ax2.set_title("Overall Sentiment Score by Label")

#plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# create a pivot table to reshape the data
pivot_table = news.pivot_table(index='date', values='overall_sentiment_score')

# create a line plot
fig, ax = plt.subplots(figsize=(12,6))
pivot_table.plot(kind='line', ax=ax)

# add labels and title
ax.set_xlabel('Date')
ax.set_ylabel('Overall Sentiment Score')
ax.set_title('Overall Sentiment Score by Label')

# show the plot
plt.show()

# %%
pip install mpld3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mpld3
#   Downloading mpld3-0.5.9-py3-none-any.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.2/201.2 kB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from mpld3) (3.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from mpld3) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->mpld3) (2.1.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mpld3) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mpld3) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mpld3) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mpld3) (8.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mpld3) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mpld3) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mpld3) (2.8.2)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mpld3) (1.22.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mpld3) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mpld3) (23.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->mpld3) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->mpld3) (1.16.0)
# Installing collected packages: mpld3
# Successfully installed mpld3-0.5.9

# %%
import feedparser
import pandas as pd
import datetime

from GoogleNews import GoogleNews
import pandas as pd
import datetime

import requests
import pandas as pd
import mpld3
from google.colab import files
import os

# %%
def exel_data(company):
  news = result_df.loc[result_df['ticker'] == company]
  news['time_published'] = pd.to_datetime(news['time_published'])
  news['date'] = news['time_published'].dt.date
  news.drop('time_published', axis=1, inplace=True)
  news = news.head(5)
  news.to_csv(f"{company}.csv", index=False)
  return


def NLP_graph(company):
  
  news = result_df.loc[result_df['ticker'] == company]
  news['time_published'] = pd.to_datetime(news['time_published'])
  news['date'] = news['time_published'].dt.date
  news.drop('time_published', axis=1, inplace=True)

  # set the figure size and create subplots
  fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(12,8))
  fig.subplots_adjust(hspace=0.4)

  # plot the line graph
  pivot_table = news.pivot_table(index='date', values='overall_sentiment_score')
  pivot_table.plot(kind='line', ax=ax1)
  ax1.set_title(company + " Overall Sentiment Score over Time", fontsize=24)

  # plot the bar graph
  news_bar = news.groupby(['date', 'overall_sentiment_label'])['overall_sentiment_score'].sum().unstack()
  news_bar.plot(kind='bar', stacked=True, ax=ax2)
  ax2.set_xlabel('Date')
  ax2.set_ylabel('Overall Sentiment Score')
  ax2.legend(title='Sentiment Label', loc='upper left')
  ax2.set_title(company + " Overall Sentiment Score by Label", fontsize=24)

  # Convert the figure to HTML format
  html_fig = mpld3.fig_to_html(fig)
  # Save the HTML to a file
  with open(f"{company}.html", 'w') as f:
      f.write(html_fig)
  files.download(company + ".html")
  
  return

# %%
company = ['MSFT','AMZN','GOOG','IBM']
for i in company:
  NLP_graph(i)
  news = result_df.loc[result_df['ticker'] == i]
  news = news.head(5)
  news.to_csv(f"{i}.csv", index=False)
# Out:
# <ipython-input-23-79b5a83288c0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news['time_published'] = pd.to_datetime(news['time_published'])
# <ipython-input-23-79b5a83288c0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news['date'] = news['time_published'].dt.date
# <ipython-input-23-79b5a83288c0>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news.drop('time_published', axis=1, inplace=True)
# <ipython-input-23-79b5a83288c0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news['time_published'] = pd.to_datetime(news['time_published'])
# <ipython-input-23-79b5a83288c0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news['date'] = news['time_published'].dt.date
# <ipython-input-23-79b5a83288c0>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news.drop('time_published', axis=1, inplace=True)
# <ipython-input-23-79b5a83288c0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news['time_published'] = pd.to_datetime(news['time_published'])
# <ipython-input-23-79b5a83288c0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news['date'] = news['time_published'].dt.date
# <ipython-input-23-79b5a83288c0>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news.drop('time_published', axis=1, inplace=True)
# <ipython-input-23-79b5a83288c0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news['time_published'] = pd.to_datetime(news['time_published'])
# <ipython-input-23-79b5a83288c0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news['date'] = news['time_published'].dt.date
# <ipython-input-23-79b5a83288c0>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news.drop('time_published', axis=1, inplace=True)

# %%
company = 'GOOG'
news = result_df.loc[result_df['ticker'] == company]
news = news.head(5)
news.to_csv(f"{company}.csv", index=False)
news
# Out:
#     ticker relevance_score ticker_sentiment_score ticker_sentiment_label  \
# 5     GOOG        0.218161               0.180128       Somewhat-Bullish
# 18    GOOG        0.171851               0.218563       Somewhat-Bullish
# 39    GOOG        0.007134               0.074025                Neutral
# 98    GOOG        0.150122                    0.0                Neutral
# 102   GOOG        0.054607               0.099006                Neutral
#
#                                                  title      time_published  \
# 5    Amid big drop in sales, PC makers may soon be ... 2023-04-11 01:43:00
# 18   Smart Speaker Market size to grow by USD 16,65... 2023-04-11 00:00:00
# 39         Time to Spring-Clean...Your Stock Portfolio 2023-04-10 22:25:00
# 98   Apple Macbook shipments lead PC drop as supply... 2023-04-10 16:55:00
# 102  Note Taking App Market Analysis: Major Drivers... 2023-04-10 15:30:00
#
#      overall_sentiment_score overall_sentiment_label
# 5                  -0.059768                 Neutral
# 18                  0.281867        Somewhat-Bullish
# 39                  0.106006                 Neutral
# 98                 -0.079281                 Neutral
# 102                 0.242911        Somewhat-Bullish
